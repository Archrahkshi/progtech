# %%
sizes = (100, 500, 1000, 5000, 10000, 50000, 100000)

from dataclasses import dataclass

@dataclass(eq=False)
class Marriage:
    groomName: str
    groomBirthday: str
    brideName: str
    brideBirthday: str
    marriageDate: str
    registryNumber: str
        
    def __gt__(self, other):
        if self.groomName > other.groomName:
            return True
        elif int(self.registryNumber) == int(other.registryNumber):
            if self.marriageDate > other.marriageDate:
                return True
            elif self.marriageDate == other.marriageDate:
                if int(self.registryNumber) > int(other.registryNumber):
                    return True
        return False
        
    def __lt__(self, other):
        if self.groomName < other.groomName:
            return True
        elif int(self.registryNumber) == int(other.registryNumber):
            if self.marriageDate < other.marriageDate:
                return True
            elif self.marriageDate == other.marriageDate:
                if int(self.registryNumber) < int(other.registryNumber):
                    return True
        return False
    
    def toStr(self):
        return ' '.join(self.__dict__.values())

def quickSort(data):
    less, pivotList, more = [], [], []
    if len(data) <= 1:
        return data
    else:
        pivot = data[0]
        for i in data:
            if i < pivot:
                less.append(i)
            elif i > pivot:
                more.append(i)
            else:
                pivotList.append(i)
        less = quickSort(less)
        more = quickSort(more)
        return less + pivotList + more

for size in sizes:
    db = open(f'databases/db{size}.txt')
    with open(f'search/sorted{size}.txt', 'w') as file:
        file.writelines(quickSort(db.readlines()))
    db.close()

marriagesSorted = {}
for size in sizes:
    with open(f'search/sorted{size}.txt') as db:
        marriagesSorted[size] = [
            Marriage(
                groomName = ' '.join(line[:3]),
                groomBirthday = line[3],
                brideName = ' '.join(line[4:7]),
                brideBirthday = line[7],
                marriageDate = line[8],
                registryNumber = line[9]
            )
        for line in map(lambda line: line.split(), db.readlines())]

marriagesUnsorted = {}   # dict<int, Marriage>
for size in sizes:
    with open(f'databases/db{size}.txt') as db:
        marriagesUnsorted[size] = [
            Marriage(
                groomName = ' '.join(line[:3]),
                groomBirthday = line[3],
                brideName = ' '.join(line[4:7]),
                brideBirthday = line[7],
                marriageDate = line[8],
                registryNumber = line[9]
            )
        for line in map(lambda line: line.split(), db.readlines())]

def linearSearch(array, query):
    for index, element in enumerate(array):
        if element == query: return index
    return None

def binarySearch(array, query):
    leftBound = 0
    rightBound = len(array) - 1
    middleBound = rightBound // 2
    while array[middleBound] != query and leftBound < rightBound:
        if query > array[middleBound]:
            leftBound = middleBound + 1
        else:
            rightBound = middleBound - 1
        middleBound = (leftBound+rightBound) // 2
    if leftBound > rightBound: 
        return None
    else: 
        return middleBound

# %%
import numpy as np
from time import time

timing = {'Прямой поиск': [], 'Бинарный поиск': [], 'Сортировка и бинарный поиск': [], 'Поиск по ключу': []}
for size in sizes:
    sortedCopy = marriagesSorted[size].copy()
    randomMarriage = sortedCopy[np.random.randint(size)]
    print(f'\nРазмер: {size}.\tЗапись:', randomMarriage.toStr())
    linearTime, binaryTime, keyTime = 0, 0, 0
    
    for _ in range(500):
        check = time()
        linearSearch(sortedCopy, randomMarriage)
        linearTime += time() - check

        check = time()
        binarySearch(sortedCopy, randomMarriage)
        binaryTime += time() - check
    
    linearTime /= 500
    print('Прямой поиск.\t\t\tНомер записи:', linearSearch(sortedCopy, randomMarriage), end='.\t')
    print('Время поиска:', linearTime)
    timing['Прямой поиск'].append(linearTime)
    
    print('Бинарный поиск.\t\t\tНомер записи:', binarySearch(sortedCopy, randomMarriage), end='.\t')
    binaryTime /= 500
    print('Время поиска:', binaryTime)
    timing['Бинарный поиск'].append(binaryTime)
    
    unsortedCopy = marriagesUnsorted[size].copy()
    check = time()
    binarySearch(quickSort(unsortedCopy), randomMarriage)
    check = time() - check
    print(f'Сортировка и бинарный поиск.\t\t\t\tВремя поиска: {check}')
    timing['Сортировка и бинарный поиск'].append(check)
    
    multimap = dict(zip(map(lambda obj: obj.toStr(), unsortedCopy), unsortedCopy))
    for _ in range(3000):
        check = time()
        multimap[randomMarriage.toStr()]
        keyTime += time() - check
    
    keyTime /= 3000
    print(f'Поиск по ключу.\t\t\t\t\t\tВремя поиска: {keyTime}')
    timing['Поиск по ключу'].append(keyTime)
# Out:
# Размер: 100.	Запись: Некрасов Ефрем Владленович 1995-01-25 Рожкова Элеонора Кузминична 1993-01-15 2020-01-26 193
# Прямой поиск.			Номер записи: 62.	Время поиска: 1.1967182159423829e-05
# Бинарный поиск.			Номер записи: 62.	Время поиска: 1.994132995605469e-06
# Сортировка и бинарный поиск.				Время поиска: 0.000997781753540039
# Поиск по ключу.						Время поиска: 1.0000069936116537e-06
#
# Размер: 500.	Запись: Петров Кир Давыдович 1985-04-17 Харитонова Юлия Вениаминовна 1984-07-31 2020-03-01 931
# Прямой поиск.			Номер записи: 326.	Время поиска: 5.0732612609863284e-05
# Бинарный поиск.			Номер записи: 326.	Время поиска: 6.102561950683594e-06
# Сортировка и бинарный поиск.				Время поиска: 0.0029675960540771484
# Поиск по ключу.						Время поиска: 9.967486063639322e-07
#
# Размер: 1000.	Запись: Сорокин Павел Изотович 1994-08-23 Рябова Фёкла Захаровна 1994-05-02 2020-02-07 63
# Прямой поиск.			Номер записи: 828.	Время поиска: 0.00012369441986083985
# Бинарный поиск.			Номер записи: 828.	Время поиска: 9.994983673095702e-06
# Сортировка и бинарный поиск.				Время поиска: 0.008014440536499023
# Поиск по ключу.						Время поиска: 9.969075520833332e-07
#
# Размер: 5000.	Запись: Егоров Назар Изотович 1989-12-23 Пономарева Анна Яковлевна 1992-09-14 2020-01-14 204
# Прямой поиск.			Номер записи: 1354.	Время поиска: 0.00020230960845947266
# Бинарный поиск.			Номер записи: 1354.	Время поиска: 1.196908950805664e-05
# Сортировка и бинарный поиск.				Время поиска: 0.061901092529296875
# Поиск по ключу.						Время поиска: 6.648699442545573e-07
#
# Размер: 10000.	Запись: Емельянов Корнил Борисович 1984-12-15 Сидорова Фёкла Олеговна 1992-10-15 2020-01-07 58
# Прямой поиск.			Номер записи: 2710.	Время поиска: 0.0004889135360717774
# Бинарный поиск.			Номер записи: 2710.	Время поиска: 7.45391845703125e-06
# Сортировка и бинарный поиск.				Время поиска: 0.09687519073486328
# Поиск по ключу.						Время поиска: 6.647904713948568e-07
#
# Размер: 50000.	Запись: Корнилов Велимир Викентьевич 1993-05-15 Фролова Евпраксия Леоновна 1987-01-30 2020-01-12 958
# Прямой поиск.			Номер записи: 21756.	Время поиска: 0.0035737924575805664
# Бинарный поиск.			Номер записи: 21756.	Время поиска: 2.008962631225586e-05
# Сортировка и бинарный поиск.				Время поиска: 0.6732664108276367
# Поиск по ключу.						Время поиска: 3.3243497212727867e-07
#
# Размер: 100000.	Запись: Цветков Фирс Архипович 1985-05-14 Гаврилова Элеонора Евгеньевна 1988-07-20 2020-01-08 890
# Прямой поиск.			Номер записи: 94796.	Время поиска: 0.015873723030090332
# Бинарный поиск.			Номер записи: 94796.	Время поиска: 2.76031494140625e-05
# Сортировка и бинарный поиск.				Время поиска: 1.5657823085784912
# Поиск по ключу.						Время поиска: 6.647109985351562e-07

# %%
from matplotlib import pyplot as plt
plt.rc(('xtick', 'ytick'), color='white')
plt.figure(figsize=(20, 10))
plt.plot(sizes, timing['Прямой поиск'], label='Прямой поиск')
plt.plot(sizes, timing['Бинарный поиск'], label='Бинарный поиск')
plt.plot(sizes, timing['Сортировка и бинарный поиск'], label='Сортировка и бинарный поиск')
plt.plot(sizes, timing['Поиск по ключу'], label='Поиск по ключу')
plt.grid()
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.savefig('lab2_search_timing.pdf')
